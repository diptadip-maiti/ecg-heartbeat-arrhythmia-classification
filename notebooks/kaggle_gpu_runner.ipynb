# %% [markdown]
# # Kaggle GPU Runner
# Clone the GitHub repository, attach the competition dataset, sanity-check it, train on GPU, and generate the submission.

# %%
# !git clone https://github.com/diptadip-maiti/ecg-heartbeat-arrhythmia-classification.git
# %cd ecg-heartbeat-arrhythmia-classification
# !pip install -q -r requirements.txt

# %%
import torch
print('CUDA available:', torch.cuda.is_available())
if torch.cuda.is_available(): print('GPU:', torch.cuda.get_device_name(0))

# %%
DATA_DIR = '/kaggle/input/.../nppe2_dataset'  # replace with attached competition path
# !python scripts/sanity_check.py --data-dir "$DATA_DIR"

# %%
# !python scripts/train.py --data-dir "$DATA_DIR" --output-dir outputs

# %%
# !python scripts/predict.py --data-dir "$DATA_DIR" --checkpoint outputs/best_model.pt --output outputs/submission.csv
